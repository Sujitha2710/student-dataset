# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('/content/student_data.csv')
student_data = data['G1']
plt.hist(student_data, bins=10, color='skyblue', edgecolor='black')
plt.xlabel('G1')
plt.ylabel('absences')
plt.title('Student grade visualization')
plt.show()
